# %% [markdown]
# <a href="https://colab.research.google.com/github/guilleunfv/tech-challenge-covid/blob/main/notebooks/analise_pnad_covid_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U gdown


import pandas as pd
import gdown


ids = {
    "maio": "1e6rRoFq4J2yVQ5qom42oJdmm3oKfBQSP",
    "julho": "1sVmlFoKZNW2U9i05dttPw3BauelTPRIs",
    "setembro": "1TuCIGyLjguNKZlZeZRILcycrrMzuzPyx"
}


arquivos = {
    "maio": "PNAD_COVID_052020.csv",
    "julho": "PNAD_COVID_072020.csv",
    "setembro": "PNAD_COVID_092020.csv"
}


for mes in ids:
    url = f"https://drive.google.com/uc?id={ids[mes]}"
    output = arquivos[mes]
    print(f"⬇️ Baixando {output} ...")
    gdown.download(url, output, quiet=False)


colunas_interesse = [
    'UF', 'A001', 'A003',                 # Estado, Sexo, Idade
    'B0011', 'B0012', 'B0013', 'B0014',   # Sintomas clínicos
    'B0015', 'B0016', 'B0017', 'B0018',
    'B0019', 'B002', 'C007', 'C008',      # Atendimento, teste e resultado
    'D0011', 'D0021', 'D0031',            # Emprego e renda
    'F001', 'F006'                        # Auxílio e trabalho remoto
]


colunas_renomeadas = {
    'UF': 'estado',
    'A001': 'sexo',
    'A003': 'idade',
    'B0011': 'sintoma_febre',
    'B0012': 'sintoma_tosse',
    'B0013': 'sintoma_garganta',
    'B0014': 'sintoma_falta_ar',
    'B0015': 'sintoma_cabeca',
    'B0016': 'sintoma_peito',
    'B0017': 'sintoma_nausea',
    'B0018': 'sintoma_diarreia',
    'B0019': 'sintoma_olfato_paladar',
    'B002': 'procurou_atendimento',
    'C007': 'fez_teste',
    'C008': 'resultado_teste',
    'D0011': 'trabalhou_semana',
    'D0021': 'rendimento_habitual',
    'D0031': 'rendimento_efetivo',
    'F001': 'recebeu_auxilio',
    'F006': 'trabalho_remoto'
}


def carregar_dados(path):
    df = pd.read_csv(path, sep=",", encoding="utf-8", usecols=colunas_interesse, engine="python")
    df.rename(columns=colunas_renomeadas, inplace=True)
    return df


df_maio = carregar_dados(arquivos["maio"])
df_julho = carregar_dados(arquivos["julho"])
df_setembro = carregar_dados(arquivos["setembro"])


for nome, df in zip(["Maio", "Julho", "Setembro"], [df_maio, df_julho, df_setembro]):
    print(f"\n📊 {nome} - {df.shape[0]} linhas, {df.shape[1]} colunas")
    display(df.head(3))
# Out:
# ...
# ⬇️ Baixando PNAD_COVID_052020.csv ...
# Downloading...
# From: https://drive.google.com/uc?id=1e6rRoFq4J2yVQ5qom42oJdmm3oKfBQSP
# To: /content/PNAD_COVID_052020.csv
# 100%|██████████| 88.0M/88.0M [00:00<00:00, 181MB/s]
# ⬇️ Baixando PNAD_COVID_072020.csv ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1sVmlFoKZNW2U9i05dttPw3BauelTPRIs
# From (redirected): https://drive.google.com/uc?id=1sVmlFoKZNW2U9i05dttPw3BauelTPRIs&confirm=t&uuid=b0e40c82-0350-43c3-ab56-96d084bf0beb
# To: /content/PNAD_COVID_072020.csv
# 100%|██████████| 115M/115M [00:00<00:00, 117MB/s]
# ⬇️ Baixando PNAD_COVID_092020.csv ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1TuCIGyLjguNKZlZeZRILcycrrMzuzPyx
# From (redirected): https://drive.google.com/uc?id=1TuCIGyLjguNKZlZeZRILcycrrMzuzPyx&confirm=t&uuid=7b96d02b-1200-4397-8909-cc58e4a3c56f
# To: /content/PNAD_COVID_092020.csv
# 100%|██████████| 115M/115M [00:00<00:00, 132MB/s]
# 📊 Maio - 349306 linhas, 20 colunas
# ...

# %%
df_maio.isna().sum()
# Out:
# estado                         0
# sexo                           0
# idade                          0
# sintoma_febre                  0
# sintoma_tosse                  0
# sintoma_garganta               0
# sintoma_falta_ar               0
# sintoma_cabeca                 0
# sintoma_peito                  0
# sintoma_nausea                 0
# sintoma_diarreia               0
# sintoma_olfato_paladar         0
# procurou_atendimento      311140
# fez_teste                 209019
# resultado_teste           212966
# trabalhou_semana               0
# rendimento_habitual            0
# rendimento_efetivo             0
# recebeu_auxilio                0
# trabalho_remoto            16691
# dtype: int64

# %%
import pandas as pd

# Diccionario com os DataFrames que já temos na memória
bases = {
    'Maio 2020': df_maio,
    'Julho 2020': df_julho,
    'Setembro 2020': df_setembro
}

# Função: devolve contagem e porcentagem de nulos
def resumo_nulos(df):
    falta = df.isna().sum()
    perc  = (falta / len(df) * 100).round(1)
    return pd.DataFrame({'Ausentes': falta, '%': perc})

# Construir um único DataFrame de resumo
resumos = {}
for nome, df in bases.items():
    resumos[nome] = resumo_nulos(df)

# Exibir resumo para cada mês
for nome in resumos:
    print(f"\n--- {nome} ---")
    display(resumos[nome].sort_values('Ausentes', ascending=False))
# Out:
# --- Maio 2020 ---
#                         Ausentes     %
# procurou_atendimento      311140  89.1
# resultado_teste           212966  61.0
# fez_teste                 209019  59.8
# trabalho_remoto            16691   4.8
# sintoma_febre                  0   0.0
# idade                          0   0.0
# sexo                           0   0.0
# estado                         0   0.0
# sintoma_tosse                  0   0.0
# sintoma_garganta               0   0.0
# sintoma_falta_ar               0   0.0
# sintoma_cabeca                 0   0.0
# sintoma_olfato_paladar         0   0.0
# sintoma_diarreia               0   0.0
# sintoma_nausea                 0   0.0
# sintoma_peito                  0   0.0
# trabalhou_semana               0   0.0
# rendimento_habitual            0   0.0
# rendimento_efetivo             0   0.0
# recebeu_auxilio                0   0.0
# --- Julho 2020 ---
#                         Ausentes     %
# procurou_atendimento      358733  93.4
# ...

# %%
def tratar_nulos(df):
    df = df.copy()                    # evita modificar vista
    # 1) procurou_atendimento & fez_teste – nulos→2
    df[['procurou_atendimento','fez_teste']] = (
        df[['procurou_atendimento','fez_teste']].fillna(2)
    )

    # 2) resultado_teste
    mapa_res = {48:'Positivo', 12:'Negativo', 36:'Indeterminado'}
    df['resultado_teste'] = (
        df['resultado_teste'].map(mapa_res).fillna('Sem Teste')
    )

    # 3) trabalho_remoto – nulos→2
    df['trabalho_remoto'] = df['trabalho_remoto'].fillna(2)

    # 4) mapear 1/2 → Sim/Não
    bin_cols = ['sintoma_febre','sintoma_tosse','sintoma_garganta','sintoma_falta_ar',
                'sintoma_cabeca','sintoma_peito','sintoma_nausea','sintoma_diarreia',
                'sintoma_olfato_paladar','procurou_atendimento','fez_teste','trabalho_remoto']
    df[bin_cols] = df[bin_cols].replace({1:'Sim', 2:'Não'})
    return df

# %%
import os

os.makedirs("data/cleaned", exist_ok=True)

df_maio.to_csv("data/cleaned/PNAD_COVID_052020_clean.csv", index=False)
df_julho.to_csv("data/cleaned/PNAD_COVID_072020_clean.csv", index=False)
df_setembro.to_csv("data/cleaned/PNAD_COVID_092020_clean.csv", index=False)

print("✅ 3 arquivos limpos exportados para data/cleaned/")
# Out:
# ✅ 3 arquivos limpos exportados para data/cleaned/

# %%
# !ls -R
# Out:
# .:
# data		       PNAD_COVID_072020.csv  sample_data
# PNAD_COVID_052020.csv  PNAD_COVID_092020.csv
#
# ./data:
# cleaned
#
# ./data/cleaned:
# PNAD_COVID_052020_clean.csv  PNAD_COVID_092020_clean.csv
# PNAD_COVID_072020_clean.csv
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
from google.colab import files
for f in os.listdir('data/cleaned'):
    files.download(f'data/cleaned/{f}')
